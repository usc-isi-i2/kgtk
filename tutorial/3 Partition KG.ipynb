# %% [markdown]
# ## Step 6: partition the files to follow the conventions KGTK uses for Wikidata

# %%
import sys  
sys.path.insert(0, 'tutorial')
from tutorial_setup import *
# Out:
# ALIAS: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/aliases.en.tsv.gz"
# ALL: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/all.tsv.gz"
# CLAIMS: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/claims.tsv.gz"
# DESCRIPTION: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/descriptions.en.tsv.gz"
# EXAMPLES_DIR: "/Users/amandeep/Github/kgtk/examples"
# GE: "/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/graph-embedding"
# ISA: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/derived.isa.tsv.gz"
# ITEM: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/claims.wikibase-item.tsv.gz"
# LABEL: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/labels.en.tsv.gz"
# OUT: "/Users/amandeep/Documents/kypher/wikidata_os_v5"
# P279: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/derived.P279.tsv.gz"
# P279STAR: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/derived.P279star.tsv.gz"
# PROPERTY_DATATYPES: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/metadata.property.datatypes.tsv.gz"
# Q154ALIAS: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/aliases.en.tsv.gz"
# Q154ALL: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/all.tsv.gz"
# Q154CLAIMS: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.tsv.gz"
# Q154DESCRIPTION: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/descriptions.en.tsv.gz"
# Q154ISA: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/derived.isa.tsv.gz"
# Q154ITEM: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-item.tsv.gz"
# Q154LABEL: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/labels.en.tsv.gz"
# Q154P279: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/derived.P279.tsv.gz"
# Q154P279STAR: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/derived.P279star.tsv.gz"
# Q154PROPERTY_DATATYPES: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/metadata.property.datatypes.tsv.gz"
# Q154QUALIFIERS: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz"
# Q154QUALIFIERS_TIME: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.time.tsv.gz"
# Q154SITELINKS: "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.tsv.gz"
# QUALIFIERS: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/qualifiers.tsv.gz"
# QUALIFIERS_TIME: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/qualifiers.time.tsv.gz"
# SITELINKS: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/sitelinks.tsv.gz"
# STORE: "/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/wikidata.sqlite3.db"
# TE: "/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/text-embedding"
# TEMP: "/Users/amandeep/Documents/kypher/temp.wikidata_os_v5"
# WIKIDATA: "/Volumes/GoogleDrive/Shared drives/KGTK/datasets/wikidataos-v4/"
# kgtk: "time kgtk --debug"
# kypher: "kgtk query --graph-cache /Users/amandeep/Documents/kypher/temp.wikidata_os_v5/wikidata.sqlite3.db"

# %%
# %cd {output_path}
# Out:
# /Users/amandeep/Documents/kypher

# %% [markdown]
# We'll use the partition-wikidata notebook to complete this step. This notebook expects an input file that includes all edges and qualifiers together. We also need to specify a directory where partitioned files should be created, and a directory where temporary files can be sent (this should be different from our temp directory as the partition notebook will clear any existing files in this folder).

# %%
# !mkdir -p $OUT/parts

# %%
# !$kgtk cat -i $OUT/all.tsv.gz -i $OUT/qualifiers.tsv.gz -o $TEMP/all_and_qualifiers.tsv.gz
# Out:
#         5.83 real         5.64 user         0.11 sys

# %%
# !zcat < $TEMP/all_and_qualifiers.tsv.gz | head
# Out:
# id	node1	label	node2
# P10-P1628-32b85d-7927ece6-0	P10	P1628	"http://www.w3.org/2006/vcard/ns#Video"
# P10-P1628-acf60d-b8950832-0	P10	P1628	"https://schema.org/video"
# P10-P1629-Q34508-bcc39400-0	P10	P1629	Q34508
# P10-P1659-P1651-c4068028-0	P10	P1659	P1651
# P10-P1659-P18-5e4b9c4f-0	P10	P1659	P18
# P10-P1659-P4238-d21d1ac0-0	P10	P1659	P4238
# P10-P1659-P51-86aca4c5-0	P10	P1659	P51
# P10-P1855-Q15075950-7eff6d65-0	P10	P1855	Q15075950
# P10-P1855-Q69063653-c8cdb04c-0	P10	P1855	Q69063653
# zcat: error writing to output: Broken pipe

# %%
pm.execute_notebook(
    os.environ["EXAMPLES_DIR"] + "/partition-wikidata.ipynb",
    os.environ["TEMP"] + "/partition-wikidata.out.ipynb",
    parameters=dict(
        wikidata_input_path = os.environ["TEMP"] + "/all_and_qualifiers.tsv.gz",
        wikidata_parts_path = os.environ["OUT"] + "/parts",
        temp_folder_path = os.environ["OUT"] + "/parts/temp",
        sort_extras = "--buffer-size 30% --temporary-directory $OUT/parts/temp",
        verbose = False
    )
)
# Out:
# Executing:   0%|          | 0/49 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:01.856499',
#      'end_time': '2021-01-14T18:06:01.878716',
#      'duration': 0.022217,
#      'status': 'completed'}},
#    'source': '# Partitioning a subset of Wikidata\n\nThis notebook illustrates how to partition a Wikidata KGTK edges file.\n\nParameters are set up in the first cell so that we can run this notebook in batch mode. Example invocation command:\n\n```\npapermill partition-wikidata.ipynb partition-wikidata.out.ipynb \\\n-p wikidata_input_path /data3/rogers/kgtk/gd/kgtk_public_graphs/cache/wikidata-20201130/data/all.tsv.gz \\\n-p wikidata_parts_path /data3/rogers/kgtk/gd/kgtk_public_graphs/cache/wikidata-20201130/parts \\\n```\n\nHere is a sample of the records that might appear in the input KGTK file:\n```\nid\tnode1\tlabel\tnode2\trank\tnode2;wikidatatype\tlang\nQ1-P1036-418bc4-78f5a565-0\tQ1\tP1036\t"113"\tnormal\texternal-id\t\nQ1-P1343-Q19190511-ab132b87-0   Q1      P1343   Q19190511       normal  wikibase-item   \nQ1-P18-92a7b3-0dcac501-0        Q1      P18     "Hubble ultra deep field.jpg"   normal  commonsMedia    \nQ1-P2386-cedfb0-0fdbd641-0      Q1      P2386   +880000000000000000000000Q828224        normal  quantity        \nQ1-P580-a2fccf-63cf4743-0       Q1      P580    ^-13798000000-00-00T00:00:00Z/3 normal  time    \nQ1-P920-47c0f2-52689c4e-0       Q1      P920    "LEM201201756"  normal  string  \nQ1-P1343-Q19190511-ab132b87-0-P805-Q84065667-0  Q1-P1343-Q19190511-ab132b87-0   P805    Q84065667               wikibase-item   \nQ1-P1343-Q88672152-5080b9e2-0-P304-5724c3-0     Q1-P1343-Q88672152-5080b9e2-0   P304    "13-36"         string  \nQ1-P2670-Q18343-030eb87e-0-P1107-ce87f8-0       Q1-P2670-Q18343-030eb87e-0      P1107   +0.70           quantity        \nQ1-P793-Q273508-1900d69c-0-P585-a2fccf-0        Q1-P793-Q273508-1900d69c-0      P585    ^-13798000000-00-00T00:00:00Z/3         time    \nP10-alias-en-282226-0   P10     alias   \'gif\'@en\nP10-description-en      P10     description     \'relevant video. For images, use the property P18. For film trailers, qualify with \\"object has role\\" (P3831)=\\"trailer\\" (Q622550)\'@en                        en\nP10-label-en    P10     label   \'video\'@en                      en\nQ1-addl_wikipedia_sitelink-19e42a-0     Q1      addl_wikipedia_sitelink http://enwikiquote.org/wiki/Universe                    en\nQ1-addl_wikipedia_sitelink-19e42a-0-language-0  Q1-addl_wikipedia_sitelink-19e42a-0     sitelink-language       en                      en\nQ1-addl_wikipedia_sitelink-19e42a-0-site-0      Q1-addl_wikipedia_sitelink-19e42a-0     sitelink-site   enwikiquote                     en\nQ1-addl_wikipedia_sitelink-19e42a-0-title-0     Q1-addl_wikipedia_sitelink-19e42a-0     sitelink-title  "Universe"                      en\nQ1-wikipedia_sitelink-5e459a-0  Q1      wikipedia_sitelink      http://en.wikipedia.org/wiki/Universe                   en\nQ1-wikipedia_sitelink-5e459a-0-badge-Q17437798  Q1-wikipedia_sitelink-5e459a-0  sitelink-badge  Q17437798                       en\nQ1-wikipedia_sitelink-5e459a-0-language-0       Q1-wikipedia_sitelink-5e459a-0  sitelink-language       en                      en\nQ1-wikipedia_sitelink-5e459a-0-site-0   Q1-wikipedia_sitelink-5e459a-0  sitelink-site   enwiki                  en\nQ1-wikipedia_sitelink-5e459a-0-title-0  Q1-wikipedia_sitelink-5e459a-0  sitelink-title  "Universe"                      en\n```\nHere are some contraints on the contents of the input file:\n- The input file starts with a KGTK header record.\n  - In addition to the `id`, `node1`, `label`, and `node2` columns, the file may contain the `node2;wikidatatype` column.\n  - The `node2;wikidatatype` column is used to partition claims by Wikidata property datatype.\n  - If it does not exist, it will be created during the partitioning process and populated using `datatype` relationships.\n  - If it does exist, any empty values in the column will be populated using `datatype` relationships.\n- The `id` column must contain a nonempty value.\n- The first section of an `id` value must be the `node` value for the record.\n  - The qualifier extraction operations depend upon th ...
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:01.899471',
#      'end_time': '2021-01-14T18:06:01.917983',
#      'duration': 0.018512,
#      'status': 'completed'}},
#    'source': "### Parameters for invoking the notebook\n\n| Parameter | Description | Default |\n| --------- | ----------- | ------- |\n| `wikidata_input_path` | A folder containing the Wikidata KGTK edges to partition. | '/data4/rogers/elicit/cache/datasets/wikidata-20200803/data/all.tsv.gz' |\n| `wikidata_parts_path` | A folder to receive the partitioned Wikidata files, such as `part.wikibase-item.tsv.gz` | '/data4/rogers/elicit/cache/datasets/wikidata-20200803/parts' |\n| `temp_folder_path` |    A folder that may be used for temporary files. | wikidata_parts_path + '/temp' |\n| `gzip_command` |        The compression command for sorting. | 'pigz'  (Note: use version 2.4 or later)|\n| `kgtk_command` |        The kgtk commmand. | 'time kgtk' |\n| `kgtk_options` |        The kgtk commmand options. | '--debug --timing' |\n| `kgtk_extension` |      The file extension for generated KGTK files. Appending `.gz` implies gzip compression. | 'tsv.gz' |\n| `presorted` |           When True, the input file is already sorted on the (`id` `node1` `label` `node2`) columns. | 'False' |\n| `sort_extras` |         Extra parameters for the sort program.  The default specifies a path for temporary files. Other useful parameters include '--buffer-size' and '--parallel'. | '--parallel 24 --buffer-size 30% --temporary-directory ' + temp_folder_path |\n| `use_mgzip` |           When True, use the mgzip program where appropriate for faster compression. | 'True' |\n| `verbose` |             When True, produce additional feedback messages. | 'True' |\n\nNote: if `pigz` version 2.4 (or later) is not available on your system, use `gzip`.\n"},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:01.935014',
#      'end_time': '2021-01-14T18:06:01.960135',
#      'duration': 0.025121,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:01.957480Z',
#      'iopub.execute_input': '2021-01-14T18:06:01.958124Z',
#      'iopub.status.idle': '2021-01-14T18:06:01.959499Z',
#      'shell.execute_reply': '2021-01-14T18:06:01.959863Z'}},
#    'outputs': [],
#    'source': "# Parameters\nwikidata_input_path = '/data3/rogers/kgtk/gd/kgtk_public_graphs/cache/wikidata-20201130/data/all.tsv.gz'\nwikidata_parts_path = '/data3/rogers/kgtk/gd/kgtk_public_graphs/cache/wikidata-20201130/parts'\ntemp_folder_path =    wikidata_parts_path + '/temp'\ngzip_command =        'pigz'\nkgtk_command =        'time kgtk'\nkgtk_options =        '--debug --timing'\nkgtk_extension =      'tsv.gz'\npresorted =           'False'\nsort_extras =         '--parallel 24 --buffer-size 30% --temporary-directory ' + temp_folder_path\nuse_mgzip =           'True'\nverbose =             'True'\n"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:01.976534',
#      'end_time': '2021-01-14T18:06:01.996950',
#      'duration': 0.020416,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:01.994391Z',
#      'iopub.execute_input': '2021-01-14T18:06:01.994879Z',
#      'iopub.status.idle': '2021-01-14T18:06:01.996472Z',
#      'shell.execute_reply': '2021-01-14T18:06:01.996804Z'}},
#    'execution_count': 2,
#    'source': '# Parameters\nwikidata_input_path = (\n    "/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/all_and_qualifiers.tsv.gz"\n)\nwikidata_parts_path = "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts"\ntemp_folder_path = "/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp"\nsort_extras = "--buffer-size 30% --temporary-directory $OUT/parts/temp"\nverbose = False\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:02.012992',
#      'end_time': '2021-01-14T18:06:02.034915',
#      'duration': 0.021923,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:02.032250Z',
#      'iopub.execute_input': '2021-01-14T18:06:02.032779Z',
#      'iopub.status.idle': '2021-01-14T18:06:02.034432Z',
#      'shell.execute_reply': '2021-01-14T18:06:02.034764Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "wikidata_input_path = '/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/all_and_qualifiers.tsv.gz'\nwikidata_parts_path = '/Users/amandeep/Documents/kypher/wikidata_os_v5/parts'\ntemp_folder_path = '/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp'\ngzip_command = 'pigz'\nkgtk_command = 'time kgtk'\nkgtk_options = '--debug --timing'\nkgtk_extension = 'tsv.gz'\npresorted = 'False'\nsort_extras = '--buffer-size 30% --temporary-directory $OUT/parts/temp'\nuse_mgzip = 'True'\nverbose = False\n"}],
#    'source': "print('wikidata_input_path = %s' % repr(wikidata_input_path))\nprint('wikidata_parts_path = %s' % repr(wikidata_parts_path))\nprint('temp_folder_path = %s' % repr(temp_folder_path))\nprint('gzip_command = %s' % repr(gzip_command))\nprint('kgtk_command = %s' % repr(kgtk_command))\nprint('kgtk_options = %s' % repr(kgtk_options))\nprint('kgtk_extension = %s' % repr(kgtk_extension))\nprint('presorted = %s' % repr(presorted))\nprint('sort_extras = %s' % repr(sort_extras))\nprint('use_mgzip = %s' % repr(use_mgzip))\nprint('verbose = %s' % repr(verbose))\n"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:02.054342',
#      'end_time': '2021-01-14T18:06:02.070012',
#      'duration': 0.01567,
#      'status': 'completed'}},
#    'source': '### Create working folders and empty them'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:02.085068',
#      'end_time': '2021-01-14T18:06:02.334787',
#      'duration': 0.249719,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:02.104189Z',
#      'iopub.execute_input': '2021-01-14T18:06:02.104761Z',
#      'iopub.status.idle': '2021-01-14T18:06:02.333978Z',
#      'shell.execute_reply': '2021-01-14T18:06:02.334539Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'mkdir: /Users/amandeep/Documents/kypher/wikidata_os_v5/parts: File exists\r\n'}],
#    'source': '!mkdir {wikidata_parts_path}\n!mkdir {temp_folder_path}'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:02.358278',
#      'end_time': '2021-01-14T18:06:02.629372',
#      'duration': 0.271094,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:02.384672Z',
#      'iopub.execute_input': '2021-01-14T18:06:02.385422Z',
#      'iopub.status.idle': '2021-01-14T18:06:02.628572Z',
#      'shell.execute_reply': '2021-01-14T18:06:02.629149Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'rm: /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/*.tsv: No such file or directory\r\nrm: /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/*.tsv.gz: No such file or directory\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'rm: /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/*.tsv: No such file or directory\r\nrm: /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/*.tsv.gz: No such file or directory\r\n'}],
#    'source': '!rm {wikidata_parts_path}/*.tsv {wikidata_parts_path}/*.tsv.gz\n!rm {temp_folder_path}/*.tsv {temp_folder_path}/*.tsv.gz'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:02.652558',
#      'end_time': '2021-01-14T18:06:02.674911',
#      'duration': 0.022353,
#      'status': 'completed'}},
#    'source': '### Sort the Input Data Unless Presorted\nSort the input data file by (id, node1, label, node2).\nThis may take a while.'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:02.696064',
#      'end_time': '2021-01-14T18:06:04.367973',
#      'duration': 1.671909,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:02.719481Z',
#      'iopub.execute_input': '2021-01-14T18:06:02.720023Z',
#      'iopub.status.idle': '2021-01-14T18:06:04.367151Z',
#      'shell.execute_reply': '2021-01-14T18:06:04.367726Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "Sorting the input file '/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/all_and_qualifiers.tsv.gz'.\n"},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.435132 CPU=0:00:00.582910 ( 40.6%): sort2 --verbose=False --gzip-command=pigz --input-file /Users/amandeep/Documents/kypher/temp.wikidata_os_v5/all_and_qualifiers.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/all.tsv.gz --columns id node1 label node2 --extra --buffer-size 30% --temporary-directory /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.536s\r\nuser\t0m2.892s\r\nsys\t0m0.202s\r\n'}],
#    'source': 'if presorted.lower() == "true": \n    print(\'Using a presorted input file %s.\' % repr(wikidata_input_path))\n    partition_input_file = wikidata_input_path \nelse: \n    print(\'Sorting the input file %s.\' % repr(wikidata_input_path))\n    partition_input_file = wikidata_parts_path + \'/all.\' + kgtk_extension \n    !{kgtk_command} {kgtk_options} sort2 --verbose={verbose} --gzip-command={gzip_command} \\\n --input-file {wikidata_input_path} \\\n --output-file {partition_input_file} \\\n --columns     id node1 label node2 \\\n --extra       "{sort_extras}"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:04.391079',
#      'end_time': '2021-01-14T18:06:04.409850',
#      'duration': 0.018771,
#      'status': 'completed'}},
#    'source': '### Partition the Claims, Qualifiers, and Entity Data\nSplit out the entity data (alias, description, label, and sitelinks) and additional metadata (datatype, type).  Separate the qualifiers from the claims.\n'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:04.426971',
#      'end_time': '2021-01-14T18:06:11.100270',
#      'duration': 6.673299,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:04.451398Z',
#      'iopub.execute_input': '2021-01-14T18:06:04.452001Z',
#      'iopub.status.idle': '2021-01-14T18:06:11.099409Z',
#      'shell.execute_reply': '2021-01-14T18:06:11.100031Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:05.888123 CPU=0:00:05.874720 ( 99.8%): filter --verbose=False --use-mgzip=True --first-match-only --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/all.tsv.gz -p ; datatype ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/metadata.property.datatypes.tsv.gz -p ; alias ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/aliases.tsv.gz -p ; description ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/descriptions.tsv.gz -p ; label ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/labels.tsv.gz -p ; addl_wikipedia_sitelink,wikipedia_sitelink ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.tsv.gz -p ; sitelink-badge,sitelink-language,sitelink-site,sitelink-title ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.qualifiers.tsv.gz -p ; type ; -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/metadata.types.tsv.gz --reject-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims-and-qualifiers.sorted-by-id.tsv.gz\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m6.531s\r\nuser\t0m5.845s\r\nsys\t0m0.130s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} filter --verbose={verbose} --use-mgzip={use_mgzip} --first-match-only \\\n --input-file {partition_input_file} \\\n -p '; datatype ;'        -o {wikidata_parts_path}/metadata.property.datatypes.{kgtk_extension} \\\n -p '; alias ;'           -o {wikidata_parts_path}/aliases.{kgtk_extension} \\\n -p '; description ;'     -o {wikidata_parts_path}/descriptions.{kgtk_extension} \\\n -p '; label ;'           -o {wikidata_parts_path}/labels.{kgtk_extension} \\\n -p '; addl_wikipedia_sitelink,wikipedia_sitelink ;' \\\n                          -o {wikidata_parts_path}/sitelinks.{kgtk_extension} \\\n -p '; sitelink-badge,sitelink-language,sitelink-site,sitelink-title ;' \\\n                          -o {wikidata_parts_path}/sitelinks.qualifiers.{kgtk_extension} \\\n -p '; type ;'            -o {wikidata_parts_path}/metadata.types.{kgtk_extension} \\\n --reject-file {temp_folder_path}/claims-and-qualifiers.sorted-by-id.{kgtk_extension}"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:11.126622',
#      'end_time': '2021-01-14T18:06:11.150925',
#      'duration': 0.024303,
#      'status': 'completed'}},
#    'source': '### Sort the claims and qualifiers on Node1\nSort the combined claims and qualifiers file by the node1 column.\nThis may take a while.'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:11.172775',
#      'end_time': '2021-01-14T18:06:12.458748',
#      'duration': 1.285973,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:11.198485Z',
#      'iopub.execute_input': '2021-01-14T18:06:11.199168Z',
#      'iopub.status.idle': '2021-01-14T18:06:12.458059Z',
#      'shell.execute_reply': '2021-01-14T18:06:12.458502Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.028628 CPU=0:00:00.641814 ( 62.4%): sort2 --verbose=False --gzip-command=pigz --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims-and-qualifiers.sorted-by-id.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims-and-qualifiers.sorted-by-node1.tsv.gz --columns node1 --extra --buffer-size 30% --temporary-directory /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp\r\n\r\nreal\t0m1.150s\r\nuser\t0m2.093s\r\nsys\t0m0.163s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} sort2 --verbose={verbose} --gzip-command={gzip_command} \\\n --input-file {temp_folder_path}/claims-and-qualifiers.sorted-by-id.{kgtk_extension} \\\n --output-file {temp_folder_path}/claims-and-qualifiers.sorted-by-node1.{kgtk_extension}\\\n --columns     node1 \\\n --extra       "{sort_extras}"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:12.483070',
#      'end_time': '2021-01-14T18:06:12.500711',
#      'duration': 0.017641,
#      'status': 'completed'}},
#    'source': "### Split the claims and qualifiers\nIf row A's node1 value matches some other row's id value, the then row A is a qualifier."},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:12.522911',
#      'end_time': '2021-01-14T18:06:18.756792',
#      'duration': 6.233881,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:12.548573Z',
#      'iopub.execute_input': '2021-01-14T18:06:12.550516Z',
#      'iopub.status.idle': '2021-01-14T18:06:18.755932Z',
#      'shell.execute_reply': '2021-01-14T18:06:18.756566Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:05.708974 CPU=0:00:05.674661 ( 99.4%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims-and-qualifiers.sorted-by-node1.tsv.gz --filter-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims-and-qualifiers.sorted-by-id.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/qualifiers.sorted-by-node1.tsv.gz --reject-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims.sorted-by-node1.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m6.090s\r\nuser\t0m5.638s\r\nsys\t0m0.158s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file {temp_folder_path}/claims-and-qualifiers.sorted-by-node1.{kgtk_extension} \\\n --filter-file {temp_folder_path}/claims-and-qualifiers.sorted-by-id.{kgtk_extension} \\\n --output-file {temp_folder_path}/qualifiers.sorted-by-node1.{kgtk_extension}\\\n --reject-file {temp_folder_path}/claims.sorted-by-node1.{kgtk_extension}\\\n --input-keys node1 \\\n --filter-keys id'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:18.784444',
#      'end_time': '2021-01-14T18:06:18.810222',
#      'duration': 0.025778,
#      'status': 'completed'}},
#    'source': '### Sort the claims by ID\nSort the split claims by id, node1, label, node2.\nThis may take a while.'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:18.833458',
#      'end_time': '2021-01-14T18:06:20.134775',
#      'duration': 1.301317,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:18.858098Z',
#      'iopub.execute_input': '2021-01-14T18:06:18.858696Z',
#      'iopub.status.idle': '2021-01-14T18:06:20.133743Z',
#      'shell.execute_reply': '2021-01-14T18:06:20.134430Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.041614 CPU=0:00:00.662223 ( 63.6%): sort2 --verbose=False --gzip-command=pigz --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims.sorted-by-node1.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims.no-datatype.tsv.gz --columns id node1 label node2 --extra --buffer-size 30% --temporary-directory /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp\r\n\r\nreal\t0m1.161s\r\nuser\t0m1.706s\r\nsys\t0m0.148s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} sort2 --verbose={verbose} --gzip-command={gzip_command} \\\n --input-file {temp_folder_path}/claims.sorted-by-node1.{kgtk_extension} \\\n --output-file {temp_folder_path}/claims.no-datatype.{kgtk_extension}\\\n --columns     id node1 label node2 \\\n --extra       "{sort_extras}"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:20.163040',
#      'end_time': '2021-01-14T18:06:20.188433',
#      'duration': 0.025393,
#      'status': 'completed'}},
#    'source': '### Merge the Wikidata Property Datatypes into the claims\nMerge the Wikidata Property Datatypes into the claims row as node2;wikidatatype. This column will be used to partition the claims by Wikidata Property Datatype ina later step.  If the claims file already has a node2;wikidatatype column, lift only when that column has an empty value.\n'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:20.212573',
#      'end_time': '2021-01-14T18:06:23.743936',
#      'duration': 3.531363,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:20.251857Z',
#      'iopub.execute_input': '2021-01-14T18:06:20.252556Z',
#      'iopub.status.idle': '2021-01-14T18:06:23.742901Z',
#      'shell.execute_reply': '2021-01-14T18:06:23.743622Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:03.082061 CPU=0:00:03.065116 ( 99.5%): lift --verbose=False --use-mgzip=True --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/claims.no-datatype.tsv.gz --columns-to-lift label --overwrite False --label-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/metadata.property.datatypes.tsv.gz --label-value datatype --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.tsv.gz --columns-to-write node2;wikidatatype\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m3.375s\r\nuser\t0m3.056s\r\nsys\t0m0.128s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} lift --verbose={verbose} --use-mgzip={use_mgzip} \\\n --input-file {temp_folder_path}/claims.no-datatype.{kgtk_extension} \\\n --columns-to-lift label \\\n --overwrite False \\\n --label-file {wikidata_parts_path}/metadata.property.datatypes.{kgtk_extension}\\\n --label-value datatype \\\n --output-file {wikidata_parts_path}/claims.{kgtk_extension}\\\n --columns-to-write 'node2;wikidatatype'"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:23.773307',
#      'end_time': '2021-01-14T18:06:23.800011',
#      'duration': 0.026704,
#      'status': 'completed'}},
#    'source': '### Sort the qualifiers by ID\nSort the split qualifiers by id, node1, label, node2.\nThis may take a while.'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:23.823361',
#      'end_time': '2021-01-14T18:06:25.003456',
#      'duration': 1.180095,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:23.847036Z',
#      'iopub.execute_input': '2021-01-14T18:06:23.847629Z',
#      'iopub.status.idle': '2021-01-14T18:06:25.002658Z',
#      'shell.execute_reply': '2021-01-14T18:06:25.003231Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:00.928583 CPU=0:00:00.658727 ( 70.9%): sort2 --verbose=False --gzip-command=pigz --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/qualifiers.sorted-by-node1.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --columns id node1 label node2 --extra --buffer-size 30% --temporary-directory /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp\r\n\r\nreal\t0m1.043s\r\nuser\t0m1.429s\r\nsys\t0m0.141s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} sort2 --verbose={verbose} --gzip-command={gzip_command} \\\n --input-file {temp_folder_path}/qualifiers.sorted-by-node1.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.{kgtk_extension}\\\n --columns     id node1 label node2 \\\n --extra       "{sort_extras}"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:25.033100',
#      'end_time': '2021-01-14T18:06:25.062571',
#      'duration': 0.029471,
#      'status': 'completed'}},
#    'source': "### Extract the English aliases, descriptions, labels, and sitelinks.\nAliases, descriptions, and labels are extracted by selecting rows where the `node2` value ends in the language suffix for English (`@en`) in a KGTK language-qualified string. This is an abbreviated pattern; a more general pattern would include the single quotes used to delimit a KGTK language-qualified string. If `kgtk import-wikidata` has executed properly, the abbreviated pattern should be sufficient.\n\nSitelink rows do not have a language-specific marker in the `node2` value. We use the `lang` column to provide the language code for English ('en').  The `lang` column is an additional column created by `kgtk import-wikidata`."},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:25.090670',
#      'end_time': '2021-01-14T18:06:26.696662',
#      'duration': 1.605992,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:25.120588Z',
#      'iopub.execute_input': '2021-01-14T18:06:25.121124Z',
#      'iopub.status.idle': '2021-01-14T18:06:26.695933Z',
#      'shell.execute_reply': '2021-01-14T18:06:26.696440Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.263460 CPU=0:00:01.259966 ( 99.7%): filter --verbose=False --use-mgzip=True --regex --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/aliases.tsv.gz -p ;; ^.*@en$ -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/aliases.en.tsv.gz\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.459s\r\nuser\t0m1.285s\r\nsys\t0m0.094s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} filter --verbose={verbose} --use-mgzip={use_mgzip} --regex \\\n --input-file {wikidata_parts_path}/aliases.{kgtk_extension} \\\n -p ';; ^.*@en$' -o {wikidata_parts_path}/aliases.en.{kgtk_extension}"},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:26.726316',
#      'end_time': '2021-01-14T18:06:28.333979',
#      'duration': 1.607663,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:26.760686Z',
#      'iopub.execute_input': '2021-01-14T18:06:26.761482Z',
#      'iopub.status.idle': '2021-01-14T18:06:28.333257Z',
#      'shell.execute_reply': '2021-01-14T18:06:28.333757Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.230002 CPU=0:00:01.228939 ( 99.9%): filter --verbose=False --use-mgzip=True --regex --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/descriptions.tsv.gz -p ;; ^.*@en$ -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/descriptions.en.tsv.gz\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.458s\r\nuser\t0m1.247s\r\nsys\t0m0.097s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} filter --verbose={verbose} --use-mgzip={use_mgzip} --regex \\\n --input-file {wikidata_parts_path}/descriptions.{kgtk_extension} \\\n -p ';; ^.*@en$' -o {wikidata_parts_path}/descriptions.en.{kgtk_extension}"},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:28.365002',
#      'end_time': '2021-01-14T18:06:30.038966',
#      'duration': 1.673964,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:28.396912Z',
#      'iopub.execute_input': '2021-01-14T18:06:28.397662Z',
#      'iopub.status.idle': '2021-01-14T18:06:30.038242Z',
#      'shell.execute_reply': '2021-01-14T18:06:30.038748Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.276782 CPU=0:00:01.276779 (100.0%): filter --verbose=False --use-mgzip=True --regex --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/labels.tsv.gz -p ;; ^.*@en$ -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/labels.en.tsv.gz\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.524s\r\nuser\t0m1.295s\r\nsys\t0m0.082s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} filter --verbose={verbose} --use-mgzip={use_mgzip} --regex \\\n --input-file {wikidata_parts_path}/labels.{kgtk_extension} \\\n -p ';; ^.*@en$' -o {wikidata_parts_path}/labels.en.{kgtk_extension}"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:30.069307',
#      'end_time': '2021-01-14T18:06:31.125859',
#      'duration': 1.056552,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:30.100623Z',
#      'iopub.execute_input': '2021-01-14T18:06:30.101317Z',
#      'iopub.status.idle': '2021-01-14T18:06:31.125069Z',
#      'shell.execute_reply': '2021-01-14T18:06:31.125631Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:00.611412 CPU=0:00:00.609809 ( 99.7%): filter --verbose=False --use-mgzip=True --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.qualifiers.tsv.gz -p ; sitelink-language ; en -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/sitelinks.language.en.tsv.gz\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m0.908s\r\nuser\t0m0.634s\r\nsys\t0m0.072s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} filter --verbose={verbose} --use-mgzip={use_mgzip} \\\n --input-file {wikidata_parts_path}/sitelinks.qualifiers.{kgtk_extension} \\\n -p '; sitelink-language ; en' -o {temp_folder_path}/sitelinks.language.en.{kgtk_extension}"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:31.156906',
#      'end_time': '2021-01-14T18:06:32.320697',
#      'duration': 1.163791,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:31.191279Z',
#      'iopub.execute_input': '2021-01-14T18:06:31.193781Z',
#      'iopub.status.idle': '2021-01-14T18:06:32.319916Z',
#      'shell.execute_reply': '2021-01-14T18:06:32.320415Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:00.612458 CPU=0:00:00.610261 ( 99.6%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/sitelinks.language.en.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.en.tsv.gz --input-keys id --filter-keys node1\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.012s\r\nuser\t0m0.637s\r\nsys\t0m0.073s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file {wikidata_parts_path}/sitelinks.{kgtk_extension} \\\n --filter-on {temp_folder_path}/sitelinks.language.en.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/sitelinks.en.{kgtk_extension} \\\n --input-keys  id \\\n --filter-keys node1'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:32.352727',
#      'end_time': '2021-01-14T18:06:33.679243',
#      'duration': 1.326516,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:32.384956Z',
#      'iopub.execute_input': '2021-01-14T18:06:32.385548Z',
#      'iopub.status.idle': '2021-01-14T18:06:33.678453Z',
#      'shell.execute_reply': '2021-01-14T18:06:33.679001Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:00.761966 CPU=0:00:00.732726 ( 96.2%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp/sitelinks.language.en.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/sitelinks.qualifiers.en.tsv.gz --input-keys node1 --filter-keys node1\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.179s\r\nuser\t0m0.764s\r\nsys\t0m0.084s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file {wikidata_parts_path}/sitelinks.qualifiers.{kgtk_extension} \\\n --filter-on {temp_folder_path}/sitelinks.language.en.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/sitelinks.qualifiers.en.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys node1'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:33.712286',
#      'end_time': '2021-01-14T18:06:33.740498',
#      'duration': 0.028212,
#      'status': 'completed'}},
#    'source': '### Partition the claims by Wikidata Property Datatype\nWikidata has two names for each Wikidata property datatype: the name that appears in the JSON dump file, and the name that appears in the TTL dump file. `kgtk import-wikidata` currently imports rows from Wikikdata JSON dump files, and these are the names that appear below.\n\nThe `part.other` file catches any records that have an unknown Wikidata property datatype. Additional Wikidata property datatypes may occur when processing from certain Wikidata extensions.'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:33.763626',
#      'end_time': '2021-01-14T18:06:37.901419',
#      'duration': 4.137793,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:33.793664Z',
#      'iopub.execute_input': '2021-01-14T18:06:33.794175Z',
#      'iopub.status.idle': '2021-01-14T18:06:37.900712Z',
#      'shell.execute_reply': '2021-01-14T18:06:37.901202Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:02.915778 CPU=0:00:02.923218 (100.3%): filter --verbose=False --use-mgzip=True --first-match-only --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.tsv.gz --obj node2;wikidatatype -p ;; commonsMedia -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.commonsMedia.tsv.gz -p ;; external-id -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.external-id.tsv.gz -p ;; geo-shape -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.geo-shape.tsv.gz -p ;; globe-coordinate -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.globe-coordinate.tsv.gz -p ;; math -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.math.tsv.gz -p ;; monolingualtext -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.monolingualtext.tsv.gz -p ;; musical-notation -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.musical-notation.tsv.gz -p ;; quantity -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.quantity.tsv.gz -p ;; string -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.string.tsv.gz -p ;; tabular-data -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.tabular-data.tsv.gz -p ;; time -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.time.tsv.gz -p ;; url -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.url.tsv.gz -p ;; wikibase-form -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-form.tsv.gz -p ;; wikibase-item -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-item.tsv.gz -p ;; wikibase-lexeme -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-lexeme.tsv.gz -p ;; wikibase-property -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-property.tsv.gz -p ;; wikibase-sense -o /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-sense.tsv.gz --reject-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.other.tsv.gz\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m3.994s\r\nuser\t0m2.892s\r\nsys\t0m0.138s\r\n'}],
#    'source': "!{kgtk_command} {kgtk_options} filter --verbose={verbose} --use-mgzip={use_mgzip} --first-match-only \\\n --input-file {wikidata_parts_path}/claims.{kgtk_extension} \\\n --obj 'node2;wikidatatype' \\\n -p ';; commonsMedia'      -o {wikidata_parts_path}/claims.commonsMedia.{kgtk_extension} \\\n -p ';; external-id'       -o {wikidata_parts_path}/claims.external-id.{kgtk_extension} \\\n -p ';; geo-shape'         -o {wikidata_parts_path}/claims.geo-shape.{kgtk_extension} \\\n -p ';; globe-coordinate'  -o {wikidata_parts_path}/claims.globe-coordinate.{kgtk_extension} \\\n -p ';; math'              -o {wikidata_parts_path}/claims.math.{kgtk_extension} \\\n -p ';; monolingualtext'   -o {wikidata_parts_path}/claims.monolingualtext.{kgtk_extension} \\\n -p ';; musical-notation'  -o {wikidata_parts_path}/claims.musical-notation.{kgtk_extension} \\\n -p ';; quantity'          -o {wikidata_parts_path}/claims.quantity.{kgtk_extension} \\\n -p ';; string'            -o {wikidata_parts_path}/claims.string.{kgtk_extension} \\\n -p ';; tabular-data'      -o {wikidata_parts_path}/claims.tabular-data.{kgtk_extension} \\\n -p ';; time'              -o {wikidata_parts_path}/claims.time.{kgtk_extension} \\\n -p ';; url'               -o {wikidata_parts_path}/claims.url.{kgtk_extension} \\\n -p ';; wikibase-form'     -o {wikidata_parts_path}/claims.wikibase-form.{kgtk_extension} \\\n -p ';; wikibase-item'     -o {wikidata_parts_path}/claims.wikibase-item.{kgtk_extension} \\\n -p ';; wikibase-lexeme'   -o {wikidata_parts_path}/claims.wikibase-lexeme.{kgtk_extension} \\\n -p ';; wikibase-property' -o {wikidata_parts_path}/claims.wikibase-property.{kgtk_extension} \\\n -p ';; wikibase-sense'    -o {wikidata_parts_path}/claims.wikibase-sense.{kgtk_extension} \\\n --reject-file {wikidata_parts_path}/claims.other.{kgtk_extension}"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:37.935869',
#      'end_time': '2021-01-14T18:06:37.965383',
#      'duration': 0.029514,
#      'status': 'completed'}},
#    'source': '### Partition the qualifiers\nExtract the qualifier records for each of the Wikidata property datatype partition files.'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:37.992924',
#      'end_time': '2021-01-14T18:06:39.594490',
#      'duration': 1.601566,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:38.019445Z',
#      'iopub.execute_input': '2021-01-14T18:06:38.020069Z',
#      'iopub.status.idle': '2021-01-14T18:06:39.593769Z',
#      'shell.execute_reply': '2021-01-14T18:06:39.594270Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.073114 CPU=0:00:01.069626 ( 99.7%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.commonsMedia.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.commonsMedia.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.461s\r\nuser\t0m1.088s\r\nsys\t0m0.081s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.commonsMedia.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.commonsMedia.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:39.627518',
#      'end_time': '2021-01-14T18:06:41.276280',
#      'duration': 1.648762,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:39.662941Z',
#      'iopub.execute_input': '2021-01-14T18:06:39.663567Z',
#      'shell.execute_reply': '2021-01-14T18:06:41.275391Z',
#      'iopub.status.idle': '2021-01-14T18:06:41.276078Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.211250 CPU=0:00:01.204261 ( 99.4%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.external-id.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.external-id.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.498s\r\nuser\t0m1.212s\r\nsys\t0m0.090s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.external-id.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.external-id.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:41.309420',
#      'end_time': '2021-01-14T18:06:42.765330',
#      'duration': 1.45591,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:41.343130Z',
#      'iopub.execute_input': '2021-01-14T18:06:41.343639Z',
#      'iopub.status.idle': '2021-01-14T18:06:42.764526Z',
#      'shell.execute_reply': '2021-01-14T18:06:42.765113Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:00.970993 CPU=0:00:00.969717 ( 99.9%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.geo-shape.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.geo-shape.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.311s\r\nuser\t0m0.991s\r\nsys\t0m0.071s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.geo-shape.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.geo-shape.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:42.799711',
#      'end_time': '2021-01-14T18:06:44.314142',
#      'duration': 1.514431,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:42.835724Z',
#      'iopub.execute_input': '2021-01-14T18:06:42.836218Z',
#      'iopub.status.idle': '2021-01-14T18:06:44.313424Z',
#      'shell.execute_reply': '2021-01-14T18:06:44.313923Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
# ...
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.831s\r\nuser\t0m1.522s\r\nsys\t0m0.087s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.quantity.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.quantity.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:50.828869',
#      'end_time': '2021-01-14T18:06:52.473290',
#      'duration': 1.644421,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:50.872001Z',
#      'iopub.execute_input': '2021-01-14T18:06:50.872700Z',
#      'iopub.status.idle': '2021-01-14T18:06:52.472559Z',
#      'shell.execute_reply': '2021-01-14T18:06:52.473068Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.080741 CPU=0:00:01.075817 ( 99.5%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.string.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.string.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.485s\r\nuser\t0m1.104s\r\nsys\t0m0.093s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.string.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.string.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:52.513210',
#      'end_time': '2021-01-14T18:06:54.139989',
#      'duration': 1.626779,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:52.557124Z',
#      'iopub.execute_input': '2021-01-14T18:06:52.557800Z',
#      'iopub.status.idle': '2021-01-14T18:06:54.139236Z',
#      'shell.execute_reply': '2021-01-14T18:06:54.139752Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.109781 CPU=0:00:01.107355 ( 99.8%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.tabular-data.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tabular-data.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.468s\r\nuser\t0m1.134s\r\nsys\t0m0.086s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.tabular-data.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.tabular-data.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:54.180010',
#      'end_time': '2021-01-14T18:06:55.717971',
#      'duration': 1.537961,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:54.224568Z',
#      'iopub.execute_input': '2021-01-14T18:06:54.225317Z',
#      'iopub.status.idle': '2021-01-14T18:06:55.717067Z',
#      'shell.execute_reply': '2021-01-14T18:06:55.717724Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.160529 CPU=0:00:01.154660 ( 99.5%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.time.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.time.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.378s\r\nuser\t0m1.170s\r\nsys\t0m0.103s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.time.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.time.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:55.757536',
#      'end_time': '2021-01-14T18:06:57.448731',
#      'duration': 1.691195,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:55.795965Z',
#      'iopub.execute_input': '2021-01-14T18:06:55.796462Z',
#      'iopub.status.idle': '2021-01-14T18:06:57.447707Z',
#      'shell.execute_reply': '2021-01-14T18:06:57.448456Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.214246 CPU=0:00:01.200573 ( 98.9%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.url.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.url.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.537s\r\nuser\t0m1.202s\r\nsys\t0m0.094s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.url.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.url.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:57.493043',
#      'end_time': '2021-01-14T18:06:59.128650',
#      'duration': 1.635607,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:57.534025Z',
#      'iopub.execute_input': '2021-01-14T18:06:57.534640Z',
#      'iopub.status.idle': '2021-01-14T18:06:59.127818Z',
#      'shell.execute_reply': '2021-01-14T18:06:59.128402Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.184961 CPU=0:00:01.172063 ( 98.9%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-form.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.wikibase-form.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.476s\r\nuser\t0m1.194s\r\nsys\t0m0.116s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.wikibase-form.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.wikibase-form.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:06:59.170165',
#      'end_time': '2021-01-14T18:07:01.576994',
#      'duration': 2.406829,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:06:59.210797Z',
#      'iopub.execute_input': '2021-01-14T18:06:59.211298Z',
#      'iopub.status.idle': '2021-01-14T18:07:01.576057Z',
#      'shell.execute_reply': '2021-01-14T18:07:01.576774Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.900496 CPU=0:00:01.885530 ( 99.2%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-item.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.wikibase-item.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m2.253s\r\nuser\t0m1.882s\r\nsys\t0m0.104s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.wikibase-item.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.wikibase-item.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:07:01.618572',
#      'end_time': '2021-01-14T18:07:03.431809',
#      'duration': 1.813237,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:07:01.661836Z',
#      'iopub.execute_input': '2021-01-14T18:07:01.662503Z',
#      'iopub.status.idle': '2021-01-14T18:07:03.430901Z',
#      'shell.execute_reply': '2021-01-14T18:07:03.431563Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.323091 CPU=0:00:01.309947 ( 99.0%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-lexeme.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.wikibase-lexeme.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.656s\r\nuser\t0m1.315s\r\nsys\t0m0.109s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.wikibase-lexeme.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.wikibase-lexeme.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:07:03.473480',
#      'end_time': '2021-01-14T18:07:05.134088',
#      'duration': 1.660608,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:07:03.513169Z',
#      'iopub.execute_input': '2021-01-14T18:07:03.513681Z',
#      'iopub.status.idle': '2021-01-14T18:07:05.132739Z',
#      'shell.execute_reply': '2021-01-14T18:07:05.133681Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.167186 CPU=0:00:01.159379 ( 99.3%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-property.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.wikibase-property.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.506s\r\nuser\t0m1.170s\r\nsys\t0m0.099s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.wikibase-property.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.wikibase-property.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'},
#   {'cell_type': 'code',
#    'execution_count': 36,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-01-14T18:07:05.176863',
#      'end_time': '2021-01-14T18:07:06.813915',
#      'duration': 1.637052,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-01-14T18:07:05.217787Z',
#      'iopub.execute_input': '2021-01-14T18:07:05.218398Z',
#      'iopub.status.idle': '2021-01-14T18:07:06.813215Z',
#      'shell.execute_reply': '2021-01-14T18:07:06.813701Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Timing: elapsed=0:00:01.066325 CPU=0:00:01.059964 ( 99.4%): ifexists --verbose=False --use-mgzip=True --presorted --input-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.tsv.gz --filter-on /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/claims.wikibase-sense.tsv.gz --output-file /Users/amandeep/Documents/kypher/wikidata_os_v5/parts/qualifiers.wikibase-sense.tsv.gz --input-keys node1 --filter-keys id\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\nreal\t0m1.477s\r\nuser\t0m1.085s\r\nsys\t0m0.089s\r\n'}],
#    'source': '!{kgtk_command} {kgtk_options} ifexists --verbose={verbose} --use-mgzip={use_mgzip} --presorted \\\n --input-file  {wikidata_parts_path}/qualifiers.{kgtk_extension} \\\n --filter-on   {wikidata_parts_path}/claims.wikibase-sense.{kgtk_extension} \\\n --output-file {wikidata_parts_path}/qualifiers.wikibase-sense.{kgtk_extension} \\\n --input-keys  node1 \\\n --filter-keys id'}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'wikidata_input_path': '/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/all_and_qualifiers.tsv.gz',
#     'wikidata_parts_path': '/Users/amandeep/Documents/kypher/wikidata_os_v5/parts',
#     'temp_folder_path': '/Users/amandeep/Documents/kypher/wikidata_os_v5/parts/temp',
#     'sort_extras': '--buffer-size 30% --temporary-directory $OUT/parts/temp',
#     'verbose': False},
#    'environment_variables': {},
#    'version': '2.2.2',
#    'input_path': '/Users/amandeep/Github/kgtk/examples/partition-wikidata.ipynb',
#    'output_path': '/Users/amandeep/Documents/kypher/temp.wikidata_os_v5/partition-wikidata.out.ipynb',
#    'start_time': '2021-01-14T18:06:01.204175',
#    'end_time': '2021-01-14T18:07:07.065526',
#    'duration': 65.861351,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 4}

# %% [markdown]
# The partition-wikidata notebook created the following partitioned kgtk-files:

# %%
# !ls $OUT/parts
# Out:
# aliases.en.tsv.gz                   metadata.property.datatypes.tsv.gz
# aliases.tsv.gz                      metadata.types.tsv.gz
# all.tsv.gz                          qualifiers.commonsMedia.tsv.gz
# claims.commonsMedia.tsv.gz          qualifiers.external-id.tsv.gz
# claims.external-id.tsv.gz           qualifiers.geo-shape.tsv.gz
# claims.geo-shape.tsv.gz             qualifiers.globe-coordinate.tsv.gz
# claims.globe-coordinate.tsv.gz      qualifiers.math.tsv.gz
# claims.math.tsv.gz                  qualifiers.monolingualtext.tsv.gz
# claims.monolingualtext.tsv.gz       qualifiers.musical-notation.tsv.gz
# claims.musical-notation.tsv.gz      qualifiers.quantity.tsv.gz
# claims.other.tsv.gz                 qualifiers.string.tsv.gz
# claims.quantity.tsv.gz              qualifiers.tabular-data.tsv.gz
# claims.string.tsv.gz                qualifiers.time.tsv.gz
# claims.tabular-data.tsv.gz          qualifiers.tsv.gz
# claims.time.tsv.gz                  qualifiers.url.tsv.gz
# claims.tsv.gz                       qualifiers.wikibase-form.tsv.gz
# claims.url.tsv.gz                   qualifiers.wikibase-item.tsv.gz
# claims.wikibase-form.tsv.gz         qualifiers.wikibase-lexeme.tsv.gz
# claims.wikibase-item.tsv.gz         qualifiers.wikibase-property.tsv.gz
# claims.wikibase-lexeme.tsv.gz       qualifiers.wikibase-sense.tsv.gz
# claims.wikibase-property.tsv.gz     sitelinks.en.tsv.gz
# claims.wikibase-sense.tsv.gz        sitelinks.qualifiers.en.tsv.gz
# descriptions.en.tsv.gz              sitelinks.qualifiers.tsv.gz
# descriptions.tsv.gz                 sitelinks.tsv.gz
# labels.en.tsv.gz                    temp
# labels.tsv.gz

# %%
# !$kypher -i $OUT/parts/claims.tsv.gz \
--match '(n1)-[]->()' \
--return 'count(distinct n1)'
# Out:
# count(DISTINCT graph_20_c1."node1")
# 16698
