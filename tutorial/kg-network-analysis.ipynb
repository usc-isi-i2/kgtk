# %% [markdown]
# # Network Analysis
#
# To-Do: write summary

# %%
import io
import os
import subprocess
import sys

import math
import numpy as np
import pandas as pd

from graph_tool.all import *

from IPython.display import display, HTML

import papermill as pm

sys.path.insert(0,'..')
from kgtk.configure_kgtk_notebooks import ConfigureKGTK

from kgtk.functions import kgtk, kypher
# Out:
# (ipykernel_launcher.py:87805): Gtk-WARNING **: 16:03:49.038: Locale not supported by C library.
# 	Using the fallback 'C' locale.

# %%
# Parameters

kgtk_path = "/Users/amandeep/GitHub/kgtk"

tutorial_deployment_path = "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets"
project_deployment_path = tutorial_deployment_path + "/arnold-network-analysis"

# Folder on local machine where to create the output and temporary folders
input_path = "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled"
output_path = "/Volumes/saggu-ssd/projects"
project_name = "tutorial-network-analysis"

# %% [markdown]
# These are all the files that we have, but I am tempted to just use the `all` file as it helps to keep the tutorial simpler

# %%
files = [
    "all",
    "label",
    "alias",
    "description",
    "external_id",
    "monolingualtext",
    "quantity",
    "string",
    "time",
    "item",
    "wikibase_property",
    "qualifiers",
    "datatypes",
    "p279",
    "p279star",
    "p31",
    "in_degree",
    "out_degree",
    "pagerank_directed",
    "pagerank_undirected"
]
ck = ConfigureKGTK(files, kgtk_path=kgtk_path)
ck.configure_kgtk(input_graph_path=input_path,
                  output_path=output_path,
                  project_name=project_name)
# Out:
# User home: /Users/amandeep
# Current dir: /Users/amandeep/Github/kgtk/tutorial
# KGTK dir: /Users/amandeep/GitHub/kgtk
# Use-cases dir: /Users/amandeep/GitHub/kgtk/use-cases

# %%
ck.print_env_variables()
# Out:
# STORE: /Volumes/saggu-ssd/projects/tutorial-network-analysis/temp.tutorial-network-analysis/wikidata.sqlite3.db
# TEMP: /Volumes/saggu-ssd/projects/tutorial-network-analysis/temp.tutorial-network-analysis
# USE_CASES_DIR: /Users/amandeep/GitHub/kgtk/use-cases
# kgtk: kgtk
# GRAPH: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled
# EXAMPLES_DIR: /Users/amandeep/GitHub/kgtk/examples
# OUT: /Volumes/saggu-ssd/projects/tutorial-network-analysis
# kypher: kgtk query --graph-cache /Volumes/saggu-ssd/projects/tutorial-network-analysis/temp.tutorial-network-analysis/wikidata.sqlite3.db
# all: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/all.tsv.gz
# label: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/labels.en.tsv.gz
# alias: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/aliases.en.tsv.gz
# description: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/descriptions.en.tsv.gz
# external_id: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.external-id.tsv.gz
# monolingualtext: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.monolingualtext.tsv.gz
# quantity: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.quantity.tsv.gz
# string: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.string.tsv.gz
# time: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.time.tsv.gz
# item: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.wikibase-item.tsv.gz
# wikibase_property: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.wikibase-property.tsv.gz
# qualifiers: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/qualifiers.tsv.gz
# datatypes: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.property.datatypes.tsv.gz
# p279: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/derived.P279.tsv.gz
# p279star: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/derived.P279star.tsv.gz
# p31: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/derived.P31.tsv.gz
# in_degree: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.in_degree.tsv.gz
# out_degree: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.out_degree.tsv.gz
# pagerank_directed: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.pagerank.directed.tsv.gz
# pagerank_undirected: /Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.pagerank.undirected.tsv.gz

# %% [markdown]
# Set up defaults KGTK

# %%
os.environ['kgtk_path'] = kgtk_path
os.environ['KGTK_GRAPH_CACHE'] = os.environ['STORE']
os.environ['KGTK_LABEL_FILE'] = input_path + "/labels.en.tsv.gz"
os.environ['KGTK_OPTION_DEBUG'] = "false"

# %% [markdown]
# Load all my files into the kypher cache so that all graph aliases are defined

# %%
# %%time
ck.load_files_into_cache()
# Out:
# kgtk query --graph-cache /Volumes/saggu-ssd/projects/tutorial-network-analysis/temp.tutorial-network-analysis/wikidata.sqlite3.db -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/all.tsv.gz" --as all  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/labels.en.tsv.gz" --as label  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/aliases.en.tsv.gz" --as alias  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/descriptions.en.tsv.gz" --as description  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.external-id.tsv.gz" --as external_id  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.monolingualtext.tsv.gz" --as monolingualtext  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.quantity.tsv.gz" --as quantity  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.string.tsv.gz" --as string  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.time.tsv.gz" --as time  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.wikibase-item.tsv.gz" --as item  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/claims.wikibase-property.tsv.gz" --as wikibase_property  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/qualifiers.tsv.gz" --as qualifiers  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.property.datatypes.tsv.gz" --as datatypes  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/derived.P279.tsv.gz" --as p279  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/derived.P279star.tsv.gz" --as p279star  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/derived.P31.tsv.gz" --as p31  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.in_degree.tsv.gz" --as in_degree  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.out_degree.tsv.gz" --as out_degree  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.pagerank.directed.tsv.gz" --as pagerank_directed  -i "/Volumes/saggu-ssd/kgtk-tutorial-files/datasets/arnold-profiled/metadata.pagerank.undirected.tsv.gz" --as pagerank_undirected  --limit 3
# node1	label	node2	id	node2;wikidatatype
# P10	alias	'gif'@en	P10-alias-en-282226-0
# P10	alias	'animation'@en	P10-alias-en-2f86d8-0
# P10	alias	'media'@en	P10-alias-en-c1427e-0
# CPU times: user 2.81 ms, sys: 13.8 ms, total: 16.6 ms
# Wall time: 1.69 s

# %%
# %cd {os.environ['OUT']}
# Out:
# /Volumes/saggu-ssd/projects/tutorial-network-analysis

# %% [markdown]
# ## Create a network of the extended family of `Arnold Schwarzenegger (Q2685)`
# We will use the following properties to build the network:
# - `child (P40)`
# - `sibling (P3373)`
# - `spouse (P26)`
# - `unmarried partner (P451)`
# - `father (P22)`
# - `mother (P25)`
#
# And we will exclude:
# - `relative (P1038)` (exclude)
#
# Approach:
# - Starting from `Arnold Schwarzenegger (Q2685)` find all the nodes that can be reached using the properties listed above
# - Extract from the KG all the edges any two nodes computed in the previous step.
#
# > Note: the `reachable-nodes` command only reports nodes, so we have to use the two steps as described above.

# %% [markdown]
# The `reachable-nodes` command can compute all the nodes reachable from a set of roots. The roots can be supplied in the command line, and for bulk processing, the root nodes can be specified in a file (it is possible to specify millions of root nodes).

# %%
# %%time
kgtk("""
    reachable-nodes -i $item
        --root Q2685
        --props P40 P3373 P26 P451 P22 P25
        --label Pextended_family
    / add-labels
""")
# Out:
# CPU times: user 9.28 ms, sys: 16.4 ms, total: 25.7 ms
# Wall time: 5.09 s
#     node1             label      node2                 node1;label  \
# 0   Q2685  Pextended_family   Q3288486  'Arnold Schwarzenegger'@en
# 1   Q2685  Pextended_family  Q23800370  'Arnold Schwarzenegger'@en
# 2   Q2685  Pextended_family  Q96076900  'Arnold Schwarzenegger'@en
# 3   Q2685  Pextended_family  Q38196234  'Arnold Schwarzenegger'@en
# 4   Q2685  Pextended_family  Q24004771  'Arnold Schwarzenegger'@en
# ..    ...               ...        ...                         ...
# 67  Q2685  Pextended_family  Q43100988  'Arnold Schwarzenegger'@en
# 68  Q2685  Pextended_family    Q901541  'Arnold Schwarzenegger'@en
# 69  Q2685  Pextended_family  Q23800185  'Arnold Schwarzenegger'@en
# 70  Q2685  Pextended_family  Q75494768  'Arnold Schwarzenegger'@en
# 71  Q2685  Pextended_family  Q75496774  'Arnold Schwarzenegger'@en
#
#                              node2;label
# 0             'Gustav Schwarzenegger'@en
# 1            'Aurelia Schwarzenegger'@en
# 2                            'Jadrny'@en
# 3           'Meinhard Schwarzenegger'@en
# 4   'Patrick M. Knapp Schwarzenegger'@en
# ..                                   ...
# 67                       'Jack Pratt'@en
# 68           'Patrick Schwarzenegger'@en
# 69                     'Joseph Baena'@en
# 70           'Mildred Patricia Baena'@en
# 71                    'Rogelio Baena'@en
#
# [72 rows x 5 columns]

# %% [markdown]
# The extended family of Arnold Schwarzenegger in the tutorial KG contains 71 people.
# We store the nodes as a new graph so that it can be used in other KGTK commands:

# %%
# %%time
kgtk("""
    reachable-nodes -i $item
        --root Q2685
        --props P40 P3373 P26 P451 P22 P25
        --label Pextended_family
        --selflink True
    -o $TEMP/arnold_family_members.tsv
""")
# Out:
# CPU times: user 4.07 ms, sys: 13.6 ms, total: 17.7 ms
# Wall time: 2.63 s

# %% [markdown]
# In step 2 we extract the edges that connect nodes in the set of reachable nodes. The `where` clause excludes the `relative (P1038)` property:

# %%
kgtk("""
    query -i item -i $TEMP/arnold_family_members.tsv
        --match '
            item: (n1)-[l {label: property}]->(n2),
            arnold: ()-[]->(n1),
            arnold: ()-[]->(n2)'
        --where 'property != "P1038"'
        --return 'distinct n1 as node1, property as label, n2 as node2'
    / add-labels
""")
# Out:
#         node1  label      node2               node1;label  \
# 0    Q1086823    P22    Q345517  'Christopher Lawford'@en
# 1    Q1086823    P25    Q432694  'Christopher Lawford'@en
# 2    Q1086823    P26  Q75326809  'Christopher Lawford'@en
# 3    Q1086823  P3373  Q75326777  'Christopher Lawford'@en
# 4    Q1086823  P3373  Q75326779  'Christopher Lawford'@en
# ..        ...    ...        ...                       ...
# 489     Q9696    P40    Q230303      'John F. Kennedy'@en
# 490     Q9696    P40    Q316064      'John F. Kennedy'@en
# 491     Q9696    P40   Q3290402      'John F. Kennedy'@en
# 492     Q9696    P40  Q75326753      'John F. Kennedy'@en
# 493     Q9696   P451      Q4616      'John F. Kennedy'@en
#
#                 label;label                    node2;label
# 0               'father'@en             'Peter Lawford'@en
# 1               'mother'@en  'Patricia Kennedy Lawford'@en
# 2               'spouse'@en         'Jean Edith Olssen'@en
# 3              'sibling'@en          'Victoria Lawford'@en
# 4              'sibling'@en            'Sydney Lawford'@en
# ..                      ...                            ...
# 489              'child'@en          'Caroline Kennedy'@en
# 490              'child'@en       'John F. Kennedy Jr.'@en
# 491              'child'@en   'Patrick Bouvier Kennedy'@en
# 492              'child'@en          'Arabelle Kennedy'@en
# 493  'unmarried partner'@en            'Marilyn Monroe'@en
#
# [494 rows x 6 columns]

# %% [markdown]
# Save the Arnold family in graph `arnold_family`:

# %%
# %%time
kgtk("""
    query -i item -i $TEMP/arnold_family_members.tsv
        --match '
            item: (n1)-[l {label: property}]->(n2),
            arnold: ()-[]->(n1),
            arnold: ()-[]->(n2)'
        --where 'property != "P1038"'
        --return 'distinct n1 as node1, property as label, n2 as node2'
    / add-id --id-style wikidata
    -o $OUT/arnold.family.tsv
""")

kgtk("query -i $OUT/arnold.family.tsv --as arnold_family --limit 10")
# Out:
# CPU times: user 9.18 ms, sys: 22.9 ms, total: 32 ms
# Wall time: 5.93 s
#       node1  label      node2                        id
# 0  Q1086823    P22    Q345517      Q1086823-P22-Q345517
# 1  Q1086823    P25    Q432694      Q1086823-P25-Q432694
# 2  Q1086823    P26  Q75326809    Q1086823-P26-Q75326809
# 3  Q1086823  P3373  Q75326777  Q1086823-P3373-Q75326777
# 4  Q1086823  P3373  Q75326779  Q1086823-P3373-Q75326779
# 5  Q1086823  P3373  Q75326780  Q1086823-P3373-Q75326780
# 6  Q1086823  P3448  Q96079835  Q1086823-P3448-Q96079835
# 7  Q1086823  P3448  Q96079836  Q1086823-P3448-Q96079836
# 8  Q1086823  P3448  Q96079838  Q1086823-P3448-Q96079838
# 9  Q1086823    P40  Q76363382    Q1086823-P40-Q76363382

# %% [markdown]
# ### Summary of this section:
# In this section:
# - We illustrated how to extract a network from a KG focusing on specific relations.
# - We built a KG with the family memebers of Arnold.

# %% [markdown]
# ## Do analytics on the Arnold family graph
#
# In this part of the tutorial we show how to use KGTK to find paths between nodes. We will use the family network we built in the previous step. We specify the source and destination nodes for the paths also as a graph, which in general can be the output of other KGTK commands. Here we built a custom file to provide a few source and destination nodes:
# > We need a nicer way to provide a portable way to define the `path-query` file so that folks can edit it.

# %%
# %%bash
# cat <<EOF >$TEMP/path-query.tsv
# node1	node2	label
# Q2685	Q4616	path
# Q9696	Q230303	path
# Q75326777	Q4616	path
# Q5112377	Q38196234	path
# EOF

# %% [markdown]
# Add labels to the path file to confirm that our input is what we want:

# %%
kgtk("""
    add-labels -i $TEMP/path-query.tsv
""")
# Out:
#        node1      node2 label                  node1;label  \
# 0      Q2685      Q4616  path   'Arnold Schwarzenegger'@en
# 1      Q9696    Q230303  path         'John F. Kennedy'@en
# 2  Q75326777      Q4616  path        'Victoria Lawford'@en
# 3   Q5112377  Q38196234  path  'Christopher G. Kennedy'@en
#
#                     node2;label
# 0           'Marilyn Monroe'@en
# 1         'Caroline Kennedy'@en
# 2           'Marilyn Monroe'@en
# 3  'Meinhard Schwarzenegger'@en

# %% [markdown]
# We invoke the `paths` command to find the shortest paths between `node1` and `node2`:

# %%
kgtk("""
    paths -i $OUT/arnold.family.tsv
        --verbose False
        --shortest-path True
        --statistics-only True
        --path-file $TEMP/path-query.tsv
    -o $TEMP/path-results.tsv
""")
# Out:
# (kgtk:87872): Gtk-WARNING **: 16:04:53.992: Locale not supported by C library.
# 	Using the fallback 'C' locale.

# %%
# !head $TEMP/path-results.tsv
# Out:
# node1	label	node2	id
# p0	0	Q2685-P26-Q230654	p0-0-0
# p0	1	Q230654-P25-Q272908	p0-1-1
# p0	2	Q272908-P3373-Q9696	p0-2-2
# p0	3	Q9696-P451-Q4616	p0-3-3
# p1	0	Q9696-P40-Q230303	p1-0-4
# p2	0	Q75326777-P25-Q432694	p2-0-5
# p2	1	Q432694-P3373-Q9696	p2-1-6
# p2	2	Q9696-P451-Q4616	p2-2-7
# p3	0	Q5112377-P22-Q25310	p3-0-8

# %% [markdown]
# In the output from the `paths` command, `node1` contains an identifier for a path, `node2` contains the edge identifier in the input graph, and `label` contains an integer to order the edges in the path.
#
# The next command uses a query to retrieve the `node1, label, node2` for each of the edges in the paths. We pipe the results through `add-labels` to help us interpret the results.

# %%
kgtk("""
    query -i arnold_family -i $TEMP/path-results.tsv
        --match '
            path: (path)-[segment]->(edge),
            arnold_family: (n1)-[edge {label: property}]->(n2)'
        --return 'n1 as node1, property as label, n2 as node2, path as path, segment as segment'
        --order-by 'path, segment'
    / add-labels
""")
# Out:
#         node1  label      node2 path  segment                    node1;label  \
# 0       Q2685    P26    Q230654   p0   p0-0-0     'Arnold Schwarzenegger'@en
# 1     Q230654    P25    Q272908   p0   p0-1-1             'Maria Shriver'@en
# 2     Q272908  P3373      Q9696   p0   p0-2-2    'Eunice Kennedy Shriver'@en
# 3       Q9696   P451      Q4616   p0   p0-3-3           'John F. Kennedy'@en
# 4       Q9696    P40    Q230303   p1   p1-0-4           'John F. Kennedy'@en
# 5   Q75326777    P25    Q432694   p2   p2-0-5          'Victoria Lawford'@en
# 6     Q432694  P3373      Q9696   p2   p2-1-6  'Patricia Kennedy Lawford'@en
# 7       Q9696   P451      Q4616   p2   p2-2-7           'John F. Kennedy'@en
# 8    Q5112377    P22     Q25310   p3   p3-0-8    'Christopher G. Kennedy'@en
# 9      Q25310  P3373    Q272908   p3   p3-1-9         'Robert F. Kennedy'@en
# 10    Q272908    P40    Q230654   p3  p3-2-10    'Eunice Kennedy Shriver'@en
# 11    Q230654    P26      Q2685   p3  p3-3-11             'Maria Shriver'@en
# 12      Q2685  P3373  Q38196234   p3  p3-4-12     'Arnold Schwarzenegger'@en
#
#                label;label                    node2;label
# 0              'spouse'@en             'Maria Shriver'@en
# 1              'mother'@en    'Eunice Kennedy Shriver'@en
# 2             'sibling'@en           'John F. Kennedy'@en
# 3   'unmarried partner'@en            'Marilyn Monroe'@en
# 4               'child'@en          'Caroline Kennedy'@en
# 5              'mother'@en  'Patricia Kennedy Lawford'@en
# 6             'sibling'@en           'John F. Kennedy'@en
# 7   'unmarried partner'@en            'Marilyn Monroe'@en
# 8              'father'@en         'Robert F. Kennedy'@en
# 9             'sibling'@en    'Eunice Kennedy Shriver'@en
# 10              'child'@en             'Maria Shriver'@en
# 11             'spouse'@en     'Arnold Schwarzenegger'@en
# 12            'sibling'@en   'Meinhard Schwarzenegger'@en

# %% [markdown]
# ### Visualization and graph analytics of the Arnold family graph
#
# The KGTK `export-gt` command makes it easy to export KGs to `graph tool` (https://graph-tool.skewed.de) , a high perfromance graph analytics and visualization tool:

# %%
# !kgtk export-gt -i $OUT/arnold.family.tsv -o $OUT/arnold.family.gt
# Out:
# (kgtk:87895): Gtk-WARNING **: 16:05:06.765: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /Users/amandeep/Github/kgtk/kgtk/exceptions.py:66: UserWarning: Please raise KGTKException instead of <class 'ModuleNotFoundError'>
#   warnings.warn('Please raise KGTKException instead of {}'.format(type_))
# KGTKException found

# %% [markdown]
# Once the graph is in `graph-tool` format, it is easy to compute networks metrics such as betweenees centrality, and to visualize the graph.
# Below is a visualization of Arnold's family graph where the color of the nodes and the thickness of the lines shows betweenees centrality:

# %%
path = os.environ["OUT"] + "/arnold.family.gt"
g = load_graph(path)

bv, be = betweenness(g)
be.a /= be.a.max() / 5
graph_draw(g, vertex_fill_color=bv, edge_pen_width=be, vertex_size=15)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7ffd1a0ffe50, at 0x7ffd1a10c820>

# %% [markdown]
# `graph-tool` is a very rich library. Here is a visualization of the hierarchical structure of Arnold's extended family:
# > More work with the library is needed to interpret the visualization (not part of this tutorial)

# %%
path = os.environ["OUT"] + "/arnold.family.gt"
g = load_graph(path)

state = minimize_nested_blockmodel_dl(g)
draw_hierarchy(state)
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x7ffd1a0fa1c0, at 0x7ffd1a117130>,
#  <Graph object, directed, with 88 vertices and 87 edges, at 0x7ffd1a141d00>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7ffd1a141d00, at 0x7ffd1a141c40>)

# %% [markdown]
# ### Summary of this section:
# In this section we:
# - Uses the `paths` command to find paths between pairs of nodes.
# - Used the `export-gt` command to export a KG to `graph tool` format.
# - Used `graph tool` to compute betweeness centrality and visualize a KG.

# %% [markdown]
# ## Connected components
# In this section we will find the connected components of the tutorial graph and clean up the graph to remove isolated small components.
#
# The KGTK command `connected-components` finds the connected components of a graph, and outputs a new graph that records the connected component that each item belongs to.

# %%
kgtk("""
    connected-components -i $item
        --minimum-cluster-size 1
        --undirected 
        -o $TEMP/item.commected_components.tsv
""")

# %% [markdown]
# The `connected-components` command outputs the connected components as a graph:

# %%
# !head $TEMP/item.commected_components.tsv
# Out:
# node1	label	node2
# Q616342	connected_component	CLUS4XI69VtenTCbHUKSPaVsaQ==
# Q7560691	connected_component	CLUS4XI69VtenTCbHUKSPaVsaQ==
# Q11445559	connected_component	CLUSAHfoFvXvhcEZd73lj1z4Bw==
# Q11524722	connected_component	CLUSAHfoFvXvhcEZd73lj1z4Bw==
# Q91096397	connected_component	CLUSC4L7DB9+AA0px63bXGxYJA==
# Q91097216	connected_component	CLUSC4L7DB9+AA0px63bXGxYJA==
# Q78607259	connected_component	CLUSCv46LgpNynxBUfoaweda7w==
# Q78607418	connected_component	CLUSCv46LgpNynxBUfoaweda7w==
# Q17239842	connected_component	CLUSETikQPaem8mOa44EYJ4hWQ==

# %% [markdown]
# Find the sizes of each of the connected components using an aggregation query:

# %%
kgtk("""
    query -i $TEMP/item.commected_components.tsv
        --match '
            (item)-[]->(component)'
        --return 'distinct component as node1, count(distinct item) as node2'
""")
# Out:
#                            node1  node2
# 0   CLUS4XI69VtenTCbHUKSPaVsaQ==      2
# 1   CLUSAHfoFvXvhcEZd73lj1z4Bw==      2
# 2   CLUSC4L7DB9+AA0px63bXGxYJA==      2
# 3   CLUSCv46LgpNynxBUfoaweda7w==      2
# 4   CLUSETikQPaem8mOa44EYJ4hWQ==      2
# 5   CLUSMsI+YaR2hce5HnpP/rq9TQ==      2
# 6   CLUSNf+5YYA4pq2TcKQzVUbL4A==      2
# 7   CLUSWhhjZiPd9C8l80phkFJu6Q==      2
# 8   CLUSiSfL49aiC4iMlarD0N2ONg==      2
# 9   CLUSnhDzMpk859X1mzkDWfSLBg==  65994
# 10  CLUSxSQ8e6AE4e+fZWi4ePHyMQ==      2

# %% [markdown]
# There is one large cluster and several small isolated clusters. We want to keep the large cluster, so we select the nodes that belong to the large cluster:

# %%
kgtk("""
    query -i $TEMP/item.commected_components.tsv
        --match '
            (item)-[]->(:`CLUSnhDzMpk859X1mzkDWfSLBg==`)'
        --return 'distinct item as node1'
    / add-labels
""")
# Out:
#            node1                                        node1;label
# 0            P10                                         'video'@en
# 1          P1000                                   'record held'@en
# 2          P1001                       'applies to jurisdiction'@en
# 3          P1004                          'MusicBrainz place ID'@en
# 4          P1005                'Portuguese National Library ID'@en
# ...          ...                                                ...
# 65989    Q999726                                'Dale Van Every'@en
# 65990    Q999734  'Albert Lasker Award for Basic Medical Researc...
# 65991  Q99975457  'Faculty of Law of the Károli Gáspár Universit...
# 65992    Q999763       'University of Paris 1 Pantheon-Sorbonne'@en
# 65993  Q99979573                   'Santa Monica Visitor Center'@en
#
# [65994 rows x 2 columns]

# %% [markdown]
# Store the large cluster graph in a file (`large-cluster.tsv`) so that we can use it in queries:
# > In this example we don't give the graph an alias; instead, we use the path where the graph is stored as an input to the `query` command. KGTK will load the graph in the cache database, and reuse it in subsequent queries:

# %%
kgtk("""
    query -i $TEMP/item.commected_components.tsv
        --match '
            (item)-[]->(:`CLUSnhDzMpk859X1mzkDWfSLBg==`)'
        --return 'distinct item as node1'
    -o $TEMP/large-cluster.tsv
""")

# %% [markdown]
# Now we want to subset the `item` graph to keep the edges that connect nodes in the large cluster, and discard the edges in the small clusters.
# We do this in a query that selects all edges from the `item` graph, as long as both nodes in the edge are in the `node1` position in the `large-cluster.tsv` graph.
# > Note that the `large-cluster` graph consists of a set of nodes stored in `node1`, and the graph has no edges. The `query` command can use graphs with no edges using the shorthand `cluster: (n1)`

# %%
# %%time
kgtk("""
    query -i $TEMP/large-cluster.tsv -i item
        --match '
            item: (n1)-[l]->(n2),
            cluster: (n1),
            cluster: (n2)'
        --return 'distinct n1 as node1, l.label as label, n2 as node2, l as id'
""")
# Out:
# CPU times: user 2.54 s, sys: 510 ms, total: 3.05 s
# Wall time: 5.94 s
#             node1  label      node2                                  id
# 0             P10    P31  Q18610173        P10-P31-Q18610173-85ef4d24-0
# 1           P1000    P31  Q18608871      P1000-P31-Q18608871-093affb5-0
# 2           P1001  P1855     Q11696       P1001-P1855-Q11696-cdbf391b-0
# 3           P1001  P1855  Q12371988    P1001-P1855-Q12371988-12c10bc0-0
# 4           P1001  P1855    Q181574      P1001-P1855-Q181574-7f428c9b-0
# ...           ...    ...        ...                                 ...
# 393699    Q999763   P463    Q868940     Q999763-P463-Q868940-d7659dce-0
# 393700  Q99979573   P131     Q47164    Q99979573-P131-Q47164-c6e86b16-0
# 393701  Q99979573    P17        Q30        Q99979573-P17-Q30-aa56b597-0
# 393702  Q99979573    P30        Q49        Q99979573-P30-Q49-ac39cd28-0
# 393703  Q99979573    P31  Q18411786  Q99979573-P31-Q18411786-39f4778f-0
#
# [393704 rows x 4 columns]

# %% [markdown]
# Compare the number of edges of our new graph consisting of the large connected component with the number of edges in the original graph.
# We use the Unix `wc` command to count the number of edges in the original `item` graph:

# %%
# !zcat< $item | wc -l
# Out:
#   393717

# %% [markdown]
# The original graph had a few more edges, so looks like our query did the job. Store the large cluster graph in a file so that we can visualize it:

# %%
# %%time
kgtk("""
    query -i $TEMP/large-cluster.tsv -i item
        --match '
            item: (n1)-[l]->(n2),
            cluster: (n1),
            cluster: (n2)'
        --return 'distinct n1 as node1, l.label as label, n2 as node2, l as id'
    / compact
    -o $OUT/item.large-cluster.tsv
""")
# Out:
# CPU times: user 6.7 ms, sys: 17.7 ms, total: 24.4 ms
# Wall time: 8.96 s

# %% [markdown]
# ### Visualization of the large connected component
#
# To compute the visualization, use the `export-gt` to export the large connected component to `graph-tool format`:

# %%
# !kgtk export-gt -i $OUT/item.large-cluster.tsv -o $OUT/item.large-cluster.gt
# Out:
# (kgtk:87953): Gtk-WARNING **: 16:05:43.903: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /Users/amandeep/Github/kgtk/kgtk/exceptions.py:66: UserWarning: Please raise KGTKException instead of <class 'ModuleNotFoundError'>
#   warnings.warn('Please raise KGTKException instead of {}'.format(type_))
# KGTKException found

# %% [markdown]
# The following code loads the graph in `graph-tool` and computes the visualization. It takes 3 minutes to compute the layout and render the visualization, so the code is commented out. An image of the visualization appears below.

# %% [markdown]
# ```
# %%time
# path = os.environ["OUT"] + "/item.large-cluster.gt"
# g = load_graph(path)
#
# pos = sfdp_layout(g)
# graph_draw(g, pos=pos, output_size=(1000, 1000))
# ```

# %% [markdown]
# Visualization of the large connected component of the tutorial graph (393,704 edges). The visualization illustrates the process we used to build the graph: we started at the `Arnold Schwarzenegger (Q2685)` and did a breath first expansion for 3 levels. Then we did a depth-first starting from the nodes representing classes to find the complete closure of the classes.
#
# ![Visualization of the tutorial graph](https://github.com/usc-isi-i2/kgtk-tutorial-files/blob/main/media/arnold-graph-vsualization.png?raw=true)

# %% [markdown]
# > The following code computes betweeness centrality of the large connected component and visualizes it

# %% [markdown]
# ```
# %%time
# path = os.environ["OUT"] + "/item.large-cluster.gt"
# g = load_graph(path)
#
# bv, be = betweenness(g)
# be.a /= be.a.max() / 5
# graph_draw(g, vertex_fill_color=bv, edge_pen_width=be, output_size=(1500, 1500))
# ```

# %% [markdown]
# ### Summary of this section
# In this section we:
# - Computed the connected components of the tutorial graph using the `connected-components` command.
# - Discovered that the tutorial graph contained one large cluster (expected) and a few isolated tiny clusters (unexpected).
# - Created a new graph discarding the tiny isolated clusters.
# - Visualized the large connected component.

# %%
# !kgtk graph-embeddings -i $OUT/arnold.family.tsv -o $OUT/arnold.family.embeddings.tsv \
--dimension 30
# Out:
# INFO:torchbiggraph:Loading entity counts...
# INFO:torchbiggraph:Creating workers...
# INFO:torchbiggraph:Initializing global model...
# INFO:torchbiggraph:Starting epoch 1 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 10.09 s ( 4.9e-05 M/sec ); io: 0.01 s ( 1.90 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:
MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.617643 , violators_lhs:  4.96761 , violators_rhs:  4.5749 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 85 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 86 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.027 M/sec ); io: 0.00 s ( 6.72 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.639208 , violators_lhs:  4.76923 , violators_rhs:  4.53036 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 86 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 87 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.026 M/sec ); io: 0.00 s ( 6.22 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.628959 , violators_lhs:  4.89069 , violators_rhs:  4.67206 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 87 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 88 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.024 M/sec ); io: 0.00 s ( 6.21 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.627988 , violators_lhs:  4.56275 , violators_rhs:  4.51417 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 88 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 89 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.024 M/sec ); io: 0.00 s ( 5.86 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.6129 , violators_lhs:  4.73887 , violators_rhs:  4.39069 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 89 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 90 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.025 M/sec ); io: 0.00 s ( 6.50 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.632927 , violators_lhs:  5.07895 , violators_rhs:  4.85628 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 90 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 91 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.026 M/sec ); io: 0.00 s ( 6.30 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.62323 , violators_lhs:  4.77328 , violators_rhs:  4.67611 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 91 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 92 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.026 M/sec ); io: 0.00 s ( 6.13 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.614523 , violators_lhs:  4.72065 , violators_rhs:  4.61943 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 92 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 93 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.025 M/sec ); io: 0.00 s ( 4.94 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.609194 , violators_lhs:  4.68623 , violators_rhs:  4.52227 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 93 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 94 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.027 M/sec ); io: 0.00 s ( 6.54 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.62628 , violators_lhs:  4.82186 , violators_rhs:  4.54049 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 94 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 95 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.027 M/sec ); io: 0.00 s ( 6.79 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.62094 , violators_lhs:  4.84615 , violators_rhs:  4.7834 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 95 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 96 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.026 M/sec ); io: 0.00 s ( 6.60 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.631319 , violators_lhs:  4.69433 , violators_rhs:  4.61741 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 96 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 97 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.029 M/sec ); io: 0.00 s ( 6.17 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.620781 , violators_lhs:  4.65992 , violators_rhs:  4.81377 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 97 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 98 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.027 M/sec ); io: 0.00 s ( 5.83 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.61733 , violators_lhs:  4.37449 , violators_rhs:  4.47976 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 98 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 99 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.025 M/sec ); io: 0.00 s ( 6.02 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.61119 , violators_lhs:  4.71053 , violators_rhs:  4.40486 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 99 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Starting epoch 100 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Edge path: /tmp/output/edges_partitioned
# INFO:torchbiggraph:still in queue: 0
# INFO:torchbiggraph:Swapping partitioned embeddings None ( 0 , 0 )
# INFO:torchbiggraph:( 0 , 0 ): Loading entities
# INFO:torchbiggraph:( 0 , 0 ): bucket 1 / 1 : Processed 494 edges in 0.02 s ( 0.026 M/sec ); io: 0.00 s ( 4.32 MB/sec )
# INFO:torchbiggraph:( 0 , 0 ): loss:  0.623575 , violators_lhs:  4.76113 , violators_rhs:  4.71457 , count:  494
# INFO:torchbiggraph:Swapping partitioned embeddings ( 0 , 0 ) None
# INFO:torchbiggraph:Writing partitioned embeddings
# INFO:torchbiggraph:Finished epoch 100 / 100, edge path 1 / 1, edge chunk 1 / 1
# INFO:torchbiggraph:Writing the metadata
# INFO:torchbiggraph:Writing the training stats
# INFO:torchbiggraph:Writing the checkpoint
# INFO:torchbiggraph:Switching to the new checkpoint version
# INFO:torchbiggraph:Exiting
# Process Finished.
# Output has been saved in '/Volumes/saggu-ssd/projects/tutorial-network-analysis/arnold.family.embeddings.tsv'

# %%
# !head $OUT/arnold.family.embeddings.tsv
# Out:
# 73 30
# Q75326809 -0.364158779 0.388267428 -0.419438183 2.596743822 -0.208671004 0.338066518 1.296220303 -1.071639895 -0.206903711 0.323908150 -0.309998572 0.245423332 -0.707402349 1.476843715 0.351142466 0.693250895 1.742361546 0.568976402 -0.533388555 -1.080772042 1.744331479 0.571251810 -0.732444048 -0.031215869 0.185505345 -0.567594528 -0.475340873 -0.354276210 0.190063432 -0.546169162
